# %%
import requests
import json

# %%
# Create variable to hold request url
url = "http://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD"

# %%
# Add format specifier to request url
url = url + "?format=json"

# %% [markdown]
# ### Execute GET request with URL

# %%
# Execute get request
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# ### Store response as variable

# %%
# Execute GET request and store response
response_data = requests.get(url)

# %% [markdown]
# ### Retrieve API output using `content` attribute

# %%
# Get content
response_content = response_data
print(response_content)
# Out:
# <Response [200]>

# %% [markdown]
# ### Use `json` function from `json` library to format

# %%
import json

# Formatting as json
data = response_data.json()

# %% [markdown]
# ### Format JSON with indents

# %%
# Add indents to JSON and output to screen
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "page": 1,
#         "pages": 317,
#         "per_page": 50,
#         "total": 15840,
#         "sourceid": "2",
#         "lastupdated": "2020-05-19"
#     },
#     [
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2019",
#             "value": null,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2018",
#             "value": 2774878865336.65,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2017",
#             "value": 2587031858037.89,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2016",
#             "value": 2511031304934.08,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2015",
#             "value": 2558415136303.56,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2014",
#             "value": 2909487527668.83,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2013",
#             "value": 2868393997444.63,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2012",
#             "value": 2787426368777.01,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2011",
#             "value": 2502151309336.19,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2010",
#             "value": 2110311385128.4,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2009",
#             "value": 1796612331466.24,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2008",
#             "value": 2078883038386.34,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2007",
#             "value": 1638461038129.09,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2006",
#             "value": 1404872078829.69,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2005",
#             "value": 1185325895537.2,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2004",
#             "value": 964490303975.315,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2003",
#             "value": 823491369713.568,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2002",
#             "value": 729327055288.617,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2001",
#             "value": 723573313180.109,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "2000",
#             "value": 735306665444.99,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1999",
#             "value": 644169176424.574,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1998",
#             "value": 591793721416.373,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1997",
#             "value": 613537110727.348,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1996",
#             "value": 578496493314.922,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1995",
#             "value": 524025780579.682,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1994",
#             "value": 487752874876.81,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1993",
#             "value": 477215990142.524,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1992",
#             "value": 471753071375.671,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1991",
#             "value": 440647680347.599,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1990",
#             "value": 446899907845.933,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1989",
#             "value": 322858249463.415,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1988",
#             "value": 307887838457.167,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1987",
#             "value": 313038961936.185,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1986",
#             "value": 293622340797.937,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1985",
#             "value": 307596819706.823,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1984",
#             "value": 310747102602.851,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1983",
#             "value": 306340792880.632,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1982",
#             "value": 326099071817.876,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1981",
#             "value": 347640120783.314,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1980",
#             "value": 337192718481.183,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1979",
#             "value": 248662024025.697,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1978",
#             "value": 183715433085.688,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1977",
#             "value": 167281724074.345,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1976",
#             "value": 145248231670.861,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1975",
#             "value": 116892363181.87,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1974",
#             "value": 105527048130.173,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1973",
#             "value": 55776364801.071,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1972",
#             "value": 44066586471.8091,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1971",
#             "value": 36946139546.6861,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "ARB",
#             "date": "1970",
#             "value": 31922305995.3365,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         }
#     ]
# ]

# %% [markdown]
# ### Identify country and GDP value for second row

# %%
# Select country and GDP value for second row
country = data[1][1]['country']['value']
gdp_value = data[1][1]['value']

print('Country: ' + str(country))
print('GRD' + str(gdp_value))
# Out:
# Country: Arab World
# GRD2774878865336.65
