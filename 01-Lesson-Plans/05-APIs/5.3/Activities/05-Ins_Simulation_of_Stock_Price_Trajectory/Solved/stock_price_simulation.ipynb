# %% [markdown]
# ### Instructor Demo: Stock Price Simulation
#
# This program executes a single simulation of stock price trajectory over the next `252` trading days (or year of trading) for `AAPL` stock, based on a normal probability distribution of historical average daily returns derived from the sample mean and standard deviation.

# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
# %matplotlib inline

# %%
# Load .env enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %% [markdown]
# ### Check Available Tickers from Alpaca Markets API

# %%
# Get all Assets
assets = api.list_assets()

# Keep only tradeable assets
tradeable = [asset for asset in assets if asset.tradable ]
tradeable
# Out:
# [Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '2a5db6a2-c035-46cc-840f-fa519740a9b5',
#      'marginable': True,
#      'name': 'LifeSci Acquisition Corp. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'LSAC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '49b90cdc-f6f5-4a7c-807a-ed172e6017af',
#      'marginable': True,
#      'name': 'American Express Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AXP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f85c0ede-3556-4d0b-9e0c-4ffc2425044d',
#      'marginable': True,
#      'name': 'Diageo plc',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'DEO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '27155f8a-2e13-4098-a54b-d63ac819aa9c',
#      'marginable': True,
#      'name': 'Main Street Capital Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MAIN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e077638f-a5c9-47e4-a7ce-2bfabf5ff698',
#      'marginable': True,
#      'name': "McDonald's Corporation",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1a35f7c5-59f3-44ed-923c-afc18a904923',
#      'marginable': True,
#      'name': 'Nautilus, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NLS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '8a181653-ab48-4e0a-b77a-388929c1ab2e',
#      'marginable': True,
#      'name': 'Annaly Capital Management, Inc. 6.95% Series F Fixed-to-Floating '
#              'Rate Cumulative Redeemable Preferre',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NLY-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'be9b6606-8994-4eeb-ba56-ede8e52b1f7e',
#      'marginable': True,
#      'name': 'Annaly Capital Management, Inc. 6.750% Series I Fixed-to-Floating '
#              'Rate Cumulative Redeemable Preferr',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NLY-I',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '68ab6a91-f696-4b18-a273-6303c43f5b2c',
#      'marginable': True,
#      'name': 'Ashford Hospitality Trust, Inc. 8.45% Series D',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHT-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '3bed4fb2-4093-4433-b887-770ae3defd3a',
#      'marginable': True,
#      'name': 'Boeing Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '2e3de94d-6d50-48ad-a535-9c02bf310969',
#      'marginable': True,
#      'name': 'Innovator S&P 500 Buffer ETF - May',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BMAY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '3411dab2-1d4d-48fd-9221-5e3107c46247',
#      'marginable': True,
#      'name': 'Collective Growth Corporation Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CGROU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '9d8f54bc-02cd-41cf-8dc4-cdf193a75743',
#      'marginable': True,
#      'name': 'VanEck Vectors China Growth Leaders ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GLCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '612794e4-dbcc-4814-8ea2-3aa1e47523e3',
#      'marginable': True,
#      'name': 'Las Vegas Sands Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'LVS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '20ebd279-1ca0-4efb-8301-26b806c05019',
#      'marginable': True,
#      'name': 'Lyra Therapeutics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'LYRA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'f3ebb16e-9676-47e8-9cb8-d9b82fce081b',
#      'marginable': True,
#      'name': 'DFP Healthcare Acquisitions Corp. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DFPH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '4d2a3f94-ddcb-49f5-aad7-3835447d163b',
#      'marginable': True,
#      'name': 'Annaly Capital Management, Inc. 7.50% Series D Cumulative '
#              'Redeemable Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NLY-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '6e3624b2-78b7-46c2-be0e-1b96a319adb0',
#      'marginable': True,
#      'name': 'Matinas BioPharma Holdings, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MTNB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '9bdade84-d6c8-4be1-aa0b-ebcb2715410e',
#      'marginable': True,
#      'name': 'Noble Energy Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NBL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '009430da-d93b-4070-808c-87b4f16261d3',
#      'marginable': True,
#      'name': 'National Retail Properties, Inc. Depositary Shares, each '
#              'representing a 1/100th interest in a share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NNN-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '19800cbd-4399-41d5-b6c3-2e1ff9a616cc',
#      'marginable': True,
#      'name': 'Innovator Nasdaq-100 Power Buffer ETF- October',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NOCT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'fae7c5ae-da92-407a-9459-755f2b3588d9',
#      'marginable': True,
#      'name': 'Nuveen Missouri Quality Municipal Income Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NOM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'b8efb1fe-8187-4be9-a8be-6f625968a3e6',
#      'marginable': True,
#      'name': 'Nuveen Pennsylvania Municipal Value Fund Common shares of '
#              'beneficial interest',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NPN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e38ac953-b460-43ec-80f6-4bb8e3d1f9b1',
#      'marginable': True,
#      'name': 'Nuveen Virginia Quality Municipal Income Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NPV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '189492ab-2136-43cf-a02b-3911ae6508e5',
#      'marginable': True,
#      'name': 'PIMCO Energy and Tactical Credit Opportunities Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRGX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '8ab5c0d2-fb63-40f4-b7bd-01fc426a7c1b',
#      'marginable': True,
#      'name': 'North European Oil Royalty Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'a6423a2d-1891-4b3d-b9e9-95b62e92b233',
#      'marginable': True,
#      'name': 'National Rural Utilities Cooperative Finance Corporation 5.500% '
#              'Subordinated Notes due 2064 (Subordi',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRUC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'cab42265-3a83-461c-9029-bd087bc5fd79',
#      'marginable': True,
#      'name': 'New Residential Investment Corp. 7.50% Series A Fixed-to-Floating '
#              'Rate Cumulative Redeemable Preferr',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRZ-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'da09a3ba-7bf7-4eac-aadc-8e8cad3ab0e7',
#      'marginable': True,
#      'name': 'New Residential Investment Corp. 6.375% Series C '
#              'Fixed-to-Floating Rate Cumulative Redeemable Prefer',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRZ-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '559320e3-acf7-4952-ac95-bff7910c6a6a',
#      'marginable': True,
#      'name': 'Plug Power, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PLUG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '004d5395-db71-4a24-b10a-c694e11d5af6',
#      'marginable': True,
#      'name': 'NUSTAR LOGISTICS, L.P. 7.625% Fixed-to-Floating Rate Subordinated '
#              'Notes due 2043',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '6ec66a76-ef9a-44b4-9c53-2dc3d9a2bafc',
#      'marginable': True,
#      'name': 'Neurotrope, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NTRP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '9265b10f-5896-4b5e-a488-bd9e45cebb52',
#      'marginable': True,
#      'name': 'Aberdeen Income Credit Strategies Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9ed8699a-ec6d-42a5-86ab-a97219bd2caf',
#      'marginable': True,
#      'name': 'New Providence Acquisition Corp. Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NPAUU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e8bc6c74-00de-45d3-bcbb-82509dc5695d',
#      'marginable': True,
#      'name': 'NeuroBo Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRBO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'db7d91f1-2886-404e-b9d3-e721c4de7fd7',
#      'marginable': True,
#      'name': 'NexPoint Real Estate Finance, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NREF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '474986a0-aab5-4e09-91c8-a3ca5ced1ce7',
#      'marginable': True,
#      'name': 'MicroSectors US Big Oil 2X Leveraged ETN',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRGO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '8d03d768-efdb-44b2-94c8-ceedf7cc7219',
#      'marginable': True,
#      'name': 'New Residential Investment Corp.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NRZ-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ff81af63-27f2-408c-b447-674d9f2af70b',
#      'marginable': True,
#      'name': 'NuStar Energy L.P. 7.625% Series B Fixed-to-Floating Rate '
#              'Cumulative Redeemable Perpetual Preferred',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NS-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9ce0b6b3-d32a-4fdd-982d-0d0c51b969d3',
#      'marginable': True,
#      'name': 'National Security Group, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NSEC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '39f25e41-5d71-4fa0-9319-1f84f18f9dac',
#      'marginable': True,
#      'name': 'NUVEEN SENIOR INCM FD',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NSL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '522bb1ad-a004-4b47-b273-a317b04ac953',
#      'marginable': True,
#      'name': 'Natuzzi, S.p.A',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NTZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '9dfedff2-739b-41ec-ba2a-939923e3c81e',
#      'marginable': True,
#      'name': 'Nuveen ESG U.S. Aggregate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NUBD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'a1e99023-c720-4791-be50-03f59176c6e8',
#      'marginable': True,
#      'name': 'Nuveen ESG High Yield Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NUHY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '8e4607cd-2a74-4ac3-bb4a-e7247d7f9593',
#      'marginable': True,
#      'name': 'Nuveen ESG Large-Cap Growth ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NULG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '3b02514c-00ba-4f7c-a3a2-662c77fbc803',
#      'marginable': True,
#      'name': 'Nuveen Michigan Quality Municipal Income Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NUM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f8ec3897-1bc8-4cba-9a68-fd7d85782d02',
#      'marginable': True,
#      'name': 'AMERICAN ASSETS TRUST, INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AAT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '599a551f-e77b-40d1-a965-7315d86d36b6',
#      'marginable': True,
#      'name': 'Atlas Air Worldwide Holdings NEW Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AAWW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '28d765e8-8085-4716-bde2-de0182b644e5',
#      'marginable': True,
#      'name': 'Axon Enterprise, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AAXN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0b666f8b-ad53-4c8e-b200-a47693ab24bf',
#      'marginable': True,
#      'name': 'Ameris Bancorp Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ABCB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a097c03a-7ebe-4de6-b729-a82370cd2a6e',
#      'marginable': True,
#      'name': 'Abbott Laboratories',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ABT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a86d6e92-8f99-4fa6-a153-c423c06dc999',
#      'marginable': True,
#      'name': 'Allegiance Bancshares, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ABTX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '110df04c-dcf5-4f92-a058-b4428876cf85',
#      'marginable': True,
#      'name': 'Associated Capital Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'dd261b3c-e46c-4afc-8cb0-0adecf282a16',
#      'marginable': True,
#      'name': 'Atlantic Capital Bancshares, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACBI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd3ce6de3-13f1-4941-94e9-f9f54174e448',
#      'marginable': True,
#      'name': 'American Campus Communities, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '681115d1-0667-442c-aa0b-c46e79ec5424',
#      'marginable': True,
#      'name': 'Acco Brands Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACCO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ca05c7af-bccb-4818-9c4f-3d1947b04cd9',
#      'marginable': True,
#      'name': 'Accel Entertainment, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACEL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ab41d7a3-9cb3-47a3-bd32-3db84a6d4806',
#      'marginable': True,
#      'name': 'Acadia Healthcare Company, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACHC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a55dcd28-50dc-4831-8a25-ee97bd91f16e',
#      'marginable': True,
#      'name': 'Acacia Communications, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACIA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ca10bf40-6b75-4e5f-9301-e753876c9b9f',
#      'marginable': True,
#      'name': 'AC Immune SA Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACIU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'fd7ecda8-13ff-43e3-81cd-50a95a5f3bc9',
#      'marginable': True,
#      'name': 'Asbury Automotive Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ABG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '82ea58a2-4bf9-424d-b00a-c718f7e07836',
#      'marginable': True,
#      'name': 'Axcelis Technologies, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACLS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd3b26730-a352-406c-95a7-502a8b1c40bc',
#      'marginable': True,
#      'name': 'Aecom',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '12774bd5-d688-43b4-b4eb-faea73c7d0fa',
#      'marginable': True,
#      'name': 'ACM Research, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACMR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6eace613-5882-4eca-8635-d1c41ee9e260',
#      'marginable': True,
#      'name': 'Accenture PLC',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '2f6c684e-6f06-4db7-8776-bac9a7093601',
#      'marginable': True,
#      'name': 'iShares MSCI ACWI ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACWI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'cf8373be-19b3-45f2-8d19-51556302da96',
#      'marginable': True,
#      'name': 'iShares MSCI ACWI ex US ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACWX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '6ca2e51d-21df-4ff0-a134-abfdbe084142',
#      'marginable': True,
#      'name': 'Automatic Data Processing, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ADP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '6e1ee27c-582e-4d0c-bf03-9dbb4f6cef6a',
#      'marginable': True,
#      'name': 'Adaptive Biotechnologies Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ADPT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '446890a6-e1e3-421d-a4cd-0185d015d45a',
#      'marginable': True,
#      'name': 'Adverum Biotechnologies, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ADVM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': 'e64da5ec-d517-456d-867f-c3c31ea7637a',
#      'marginable': True,
#      'name': 'Adams Resources & Energy Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '98ce4784-3b9a-4a4f-88ec-f2db2f1e8961',
#      'marginable': True,
#      'name': 'Ameren Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '4a63bc78-fa4c-494a-836c-467cccb1d17a',
#      'marginable': True,
#      'name': 'Aberdeen Emerging Markets Equity Income Fund, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '93cb6292-56c4-4531-b65e-e92e1dc9d0e5',
#      'marginable': True,
#      'name': 'Aehr Test Systems Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEHR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '80149eab-4700-4a98-ba25-2fff713c38ca',
#      'marginable': True,
#      'name': 'Advanced Energy Industries, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEIS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1b5fc178-c2db-4a13-85d2-cdf08c750319',
#      'marginable': True,
#      'name': 'American Equity Investment Life Holding Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '90e9c946-6323-49a4-be69-116f04fec288',
#      'marginable': True,
#      'name': 'American Electric Power Company, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b7f12b49-27b5-4d3d-8980-ae448b1db7b5',
#      'marginable': True,
#      'name': 'American Finance Trust, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AFIN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '34db7ed0-9b52-436d-a5ed-af53398d6f78',
#      'marginable': True,
#      'name': 'Affimed N.V.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AFMD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ad100351-19bb-4ce4-bcaa-46b7d5cf2cb4',
#      'marginable': True,
#      'name': 'Afya Limited Class A Common Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AFYA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '96235c9d-bcd4-4ede-9817-4b5e6a1941bf',
#      'marginable': True,
#      'name': 'AgroFresh Solutions, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGFS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '0d3076c3-d05c-4930-93ed-cc634512af40',
#      'marginable': True,
#      'name': 'Alamos Gold Inc. Class A Common Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '00f336cc-8448-4c78-aba4-be5e38b4b102',
#      'marginable': True,
#      'name': 'Agios Pharmaceuticals, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'e47878ce-5e59-4dd1-8e36-e65b38edaf9d',
#      'marginable': True,
#      'name': 'Aeglea BioTherapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGLE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7c719276-2ed5-4cec-a0f8-1a74c5dc484f',
#      'marginable': True,
#      'name': 'AGNC Investment Corp. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGNC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '38e7f438-3375-4b6b-939d-f2d20d787799',
#      'marginable': True,
#      'name': 'Assured Guaranty, LTD',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e3e63ec9-a0fa-40d4-9e07-a175675ce8c7',
#      'marginable': True,
#      'name': 'Assured Guaranty Municipal Holdings Inc. 6-7/8% Quarterly '
#              'Interest Bonds due 2101',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGO-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '3fd9b547-db79-4b47-a6bf-8b633d85cccf',
#      'marginable': True,
#      'name': 'ADECOAGRO S.A.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGRO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '77025d43-80ed-4653-b61a-8c2813a396f0',
#      'marginable': True,
#      'name': 'Agile Therapeutics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '1aadf951-8d28-4c96-b10b-d7b4a4c976ce',
#      'marginable': True,
#      'name': 'iShares MSCI Argentina and Global Exposure ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '255adf82-f431-4210-b873-4d454b1b0c62',
#      'marginable': True,
#      'name': 'Applied Genetic Technologies Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AGTC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '7b712bb0-2540-4953-9c5f-ccb526d5d13f',
#      'marginable': True,
#      'name': 'Aspen Insurance Holdings Limited Depositary Shares, each '
#              'representing a 1/1000th interest in a share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHL-E',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#      'marginable': True,
#      'name': 'Allied Healthcare Products, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ea95f4bd-026f-4c2f-89cf-0de46159bb8d',
#      'marginable': True,
#      'name': 'Ashford Hospitality Trust, Inc   7.375% Series G Cumulative '
#              'Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHT-G',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': 'c50c97c6-535f-42be-97b5-e45f6f3634fa',
#      'marginable': True,
#      'name': 'Air Industries Group',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AIRI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6a5d1d05-d652-48a6-b33f-98991c0a442a',
#      'marginable': True,
#      'name': 'Apartment Investment and Management Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AIV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '89120cf3-1d3c-49bd-88c0-8944a7a426e9',
#      'marginable': True,
#      'name': 'Assurant, Inc. 6.50% Series D Mandatory Convertible Preferred '
#              'Stock, $1.00 par value',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AIZP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '03d52475-5033-4a90-be28-2d3c174f0e86',
#      'marginable': True,
#      'name': 'Akebia Therapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AKBA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'b4318aa6-7ffc-4bf3-a6df-74296f2e12ae',
#      'marginable': True,
#      'name': 'Arbor Realty Trust, Inc. 8.50% Series C Cumulative Redeemable '
#              'Preferred Stock, Liquidation Preferenc',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ABR-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'bcff4a03-e2cd-43ff-950e-9514212d1825',
#      'marginable': True,
#      'name': 'Acamar Partners Acquisition Corp. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ACAM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'ed5208b3-3a31-4f13-be71-a34742fea2cc',
#      'marginable': True,
#      'name': 'Acer Therapeutics Inc. Common Stock (DE)',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ACER',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1a4d564c-a833-4ec5-96f0-1e0eb69161dd',
#      'marginable': True,
#      'name': 'Assured Guaranty Municipal Holdings Inc. 5.60% Notes due 2103',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGO-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '0a5e6078-0184-48c8-9552-38cf40b4df4e',
#      'marginable': True,
#      'name': 'Akero Therapeutics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AKRO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0f617181-38fb-4f29-9029-4e8948d383f2',
#      'marginable': True,
#      'name': 'Aldeyra Therapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ALDX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '9f5ab4fb-335d-41ef-83d9-4d0abbd61fde',
#      'marginable': True,
#      'name': 'The Allstate Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ALL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2f630203-b16e-463e-95a9-9f2a585138c4',
#      'marginable': True,
#      'name': 'Allegion Public Limited Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ALLE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '5d676c76-d368-455c-91a5-e349a883ac15',
#      'marginable': True,
#      'name': 'Alnylam Pharmaceuticals, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ALNY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b0ff2d40-6ec2-4fc2-a52a-a1109314114f',
#      'marginable': True,
#      'name': 'AstroNova, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ALOT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'cbc50ca6-1e19-4630-afbe-0d6239c3b3c3',
#      'marginable': True,
#      'name': 'Alithya Group inc. Class A Subordinate Voting Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ALYA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b7c91d5a-cf61-4cca-ba92-596c4b4bb6dc',
#      'marginable': True,
#      'name': 'Antero Midstream Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '61f5c7f3-31f9-49d8-9cec-d761806c0609',
#      'marginable': True,
#      'name': 'Ambac Financial Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMBC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6642e128-03ee-4bc9-bd3f-8f49424480d7',
#      'marginable': True,
#      'name': 'Ametek, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AME',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '0a826931-2c20-4707-894c-5dd5dd52855e',
#      'marginable': True,
#      'name': 'Atlas Financial Holdings, Inc. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AFH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '8068b2d4-c9d2-4322-82de-20d5b20d680c',
#      'marginable': True,
#      'name': 'Anfield Universal Fixed Income ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AFIF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '495fe213-8b70-4585-994b-6b8efa4bbfaf',
#      'marginable': True,
#      'name': 'Affiliated Managers Group',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '6882160b-3fe1-46ce-aa66-543f2f93ac6e',
#      'marginable': True,
#      'name': 'American Homes 4 Rent 6.5% Series D Cumulative Redeemable '
#              'Perpetual Preferred Shares of beneficial i',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMH-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1efd2359-0698-424e-8d61-2b27dcb4926c',
#      'marginable': True,
#      'name': 'American Homes 4 Rent 6.35% Series E Cumulative Redeemable '
#              'Perpetual Preferred Shares of Beneficial',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMH-E',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ada99a34-0e70-4e38-91e6-624f45477515',
#      'marginable': True,
#      'name': 'American Homes 4 Rent',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMH-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '37ea6698-289d-476a-8266-42d75f804473',
#      'marginable': True,
#      'name': 'American National Bankshares, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMNB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '6daa3635-4360-4f03-9d01-09232cd92f2b',
#      'marginable': True,
#      'name': 'Allied Motion Technologies, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMOT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1bd79a4c-40e4-445b-848a-0feeec0579cd',
#      'marginable': True,
#      'name': 'Amplify Energy Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMPY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'fed6f0bc-cf60-401f-aa1f-8f680ab1de5d',
#      'marginable': True,
#      'name': 'American River Bankshares Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMRB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a2192ded-0453-47c1-9428-bc023efb35f8',
#      'marginable': True,
#      'name': 'Ameresco, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMRC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '59576c8b-25c8-4a3c-8259-4467a3c4330c',
#      'marginable': True,
#      'name': 'A-Mark Precious Metals, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMRK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ddac09a2-793e-416a-b96b-a44c5f21ef65',
#      'marginable': True,
#      'name': 'Amneal Pharmaceuticals, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '084a1c38-56ff-47d0-a847-2372b4c4007f',
#      'marginable': True,
#      'name': 'Aberdeen Global Dynamic Dividend Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '326d2437-4fb8-49b1-b81f-0f375c4e872e',
#      'marginable': True,
#      'name': 'American Shared Hospital Services',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ad349cf6-ecb0-43c5-bf45-9cf7f09a1112',
#      'marginable': True,
#      'name': 'AMERISAFE, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMSF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'cead49ca-6c1f-45f6-a9b1-097a8b538703',
#      'marginable': True,
#      'name': 'American Software, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMSWA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a148da60-6af9-443b-a3a9-9d3e65eb91e9',
#      'marginable': True,
#      'name': 'American Tower Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b700cfbc-d082-4890-ade5-99e228f45ed2',
#      'marginable': True,
#      'name': 'Amerant Bancorp Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMTB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'e2c2a9f9-e4e4-4132-9b5a-0d4a8eb9381c',
#      'marginable': True,
#      'name': 'TD Ameritrade Holding Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMTD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd1247b20-5ad4-4edd-9406-f15dded33539',
#      'marginable': True,
#      'name': 'America Movil S.A.B de C.V',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '4a0326fc-6e45-4ec5-8de1-bb3de4580a29',
#      'marginable': True,
#      'name': 'InfraCap MLP ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMZA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '2e7053d2-eaff-4f03-a506-7aa5f475dca6',
#      'marginable': True,
#      'name': 'AnaptysBio, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANAB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '1ad5be1c-fc90-41ac-a17f-27a3e9021007',
#      'marginable': True,
#      'name': 'American National Insurance Company Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANAT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'fbe398cd-2618-4cca-9614-e311c3166636',
#      'marginable': True,
#      'name': 'Andina Acquisition Corp. III Ordinary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANDA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'cbfae067-8c09-47a5-86f1-276f2ece42e9',
#      'marginable': True,
#      'name': 'Arista Networks',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANET',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd01c9857-0023-4252-acb6-02dfd409159f',
#      'marginable': True,
#      'name': 'Abercrombie & Fitch Co.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '329802fe-c400-439b-bc8a-7f98107281ff',
#      'marginable': True,
#      'name': 'AngioDynamics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANGO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '3a5afd64-6d45-449f-be06-46d380808f19',
#      'marginable': True,
#      'name': 'Anworth Mortgage Asset Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '2833b5f8-ca93-424e-82e8-067ef5aca434',
#      'marginable': True,
#      'name': 'ANWORTH MORTGAGE ASSET CORPORATION 7.625% Series C Cumulative '
#              'Redeemable Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANH-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '64a63fb5-41e9-4cc3-aa89-54b8b978f9bc',
#      'marginable': True,
#      'name': 'American Outdoor Brands Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AOBC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ecd5c7b6-757f-4b29-b093-24f0a08197e5',
#      'marginable': True,
#      'name': 'Aberdeen Total Dynamic Dividend Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AOD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6c21ef75-b953-4434-8119-501a26656625',
#      'marginable': True,
#      'name': 'Aon plc Class A',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AON',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f07f3cff-5ef1-4892-bd34-a4155d984226',
#      'marginable': True,
#      'name': 'A.O. Smith Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AOS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ba197d1c-8104-4aed-9331-e2507fe04fa1',
#      'marginable': True,
#      'name': 'Ampco-Pittsburgh Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '2ac633b5-b3a7-4ba6-975d-f0f1e12dd1e4',
#      'marginable': True,
#      'name': 'Adobe Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ADBE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '57ca9916-468b-4c77-8be7-2495a7c17df2',
#      'marginable': True,
#      'name': 'Air Products & Chemicals, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'APD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '01c893ba-85d6-4ff8-93cd-6c6d6972465c',
#      'marginable': True,
# ...
#      'marginable': True,
#      'name': 'Cowen Inc. 7.75% Senior Notes due 2033',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'COWNL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b3d71bbc-0a77-454a-9ff8-03999609ffd2',
#      'marginable': True,
#      'name': 'Cowen Inc. 7.35% Senior Notes Due 2027',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'COWNZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '1dbb9e0b-5fa8-4904-bf41-3785e381b982',
#      'marginable': True,
#      'name': 'Pacer US Cash Cows 100 ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'COWZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f62dada2-7c7c-4db3-a339-242e94f832a7',
#      'marginable': True,
#      'name': 'Copa Holdings, S.A.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '335a324e-a7a2-4449-abce-312d9ddaa580',
#      'marginable': True,
#      'name': 'Conyers Park II Acquisition Corp. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPAA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '0c424fbc-147c-402c-9667-c3b2a0e64d73',
#      'marginable': True,
#      'name': 'CEMENTOS PACASMAYO S.A.A.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPAC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '7002413f-a978-458a-8c66-a37c7ecf98dc',
#      'marginable': True,
#      'name': 'CounterPath Corporation Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPAH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '023dcf58-0c66-41e5-87dc-229bef3e3333',
#      'marginable': True,
#      'name': 'Campbell Soup Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f9174608-b6bc-4d46-bfc7-4bb761883964',
#      'marginable': True,
#      'name': 'Callon Petroleum Company',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ec87a926-5908-454b-973a-787767cf4ba4',
#      'marginable': True,
#      'name': 'Central Pacific Financial Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'eb8b05d4-7107-4048-bff0-a9d53dc57c26',
#      'marginable': True,
#      'name': 'CRESCENT POINT ENERGY CORP.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '5d207be9-c364-48f4-b329-362d0893854d',
#      'marginable': True,
#      'name': "Canterbury Park Holding Corporation 'New' Common Stock",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPHC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '8ffb3147-5048-405f-9e03-971718eff8fa',
#      'marginable': True,
#      'name': 'China Pharma Holdings, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPHI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '51b5c59f-3bba-417f-b9ed-d846d9f23f3e',
#      'marginable': True,
#      'name': 'CPI Inflation Hedged ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '66403526-ca48-4efa-aaf1-6dbb847b13d7',
#      'marginable': True,
#      'name': 'AeroCentury Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ACY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '6f1d10a7-20ba-4ef0-835c-1313cc7b9ce4',
#      'marginable': True,
#      'name': 'Adaptimmune Therapeutics plc American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ADAP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '809f0a54-d2df-4706-ad11-30e3b64df82e',
#      'marginable': True,
#      'name': 'Azure Power Global Limited',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AZRE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9a32fbf7-81fa-4602-bc9e-bfab536a30aa',
#      'marginable': True,
#      'name': 'AzurRx BioPharma, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AZRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0732b282-1afd-4427-9135-91702ef95868',
#      'marginable': True,
#      'name': 'Cumberland Pharmaceuticals Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPIX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '13c4676b-e982-436f-b2d8-c1d2ebc07362',
#      'marginable': True,
#      'name': 'Chesapeake Utilities',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '268fc4eb-8c02-4d23-adeb-db5ed93323d3',
#      'marginable': True,
#      'name': 'CorePoint Lodging Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPLG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '26396043-5a22-4cc1-8ee0-d770b8e6ec7e',
#      'marginable': True,
#      'name': 'Capital Product Partners L.P. Common Units',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPLP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1a703932-f39e-4c81-8814-784d505735a2',
#      'marginable': True,
#      'name': 'Capri Holdings Limited',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPRI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3302e560-6d33-4ad5-a429-4d573e26962c',
#      'marginable': True,
#      'name': 'Copart, Inc. (DE) Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPRT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b8babba9-902a-4c5b-ac8d-cbf368b0111f',
#      'marginable': True,
#      'name': 'Catalyst Pharmaceuticals, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '3c526bde-f7bf-4222-a304-5d574ad453d3',
#      'marginable': True,
#      'name': 'CPS Technologies Corp. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPSH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b39022df-cf69-4a2e-b0eb-ea2078450a8e',
#      'marginable': True,
#      'name': 'Computer Programs and Systems, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPSI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '17d926cc-649f-48db-bf8e-330c00067d95',
#      'marginable': True,
#      'name': 'Consumer Portfolio Services, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'dc2d8be9-33b5-4a32-8f57-5b7d209d2c82',
#      'marginable': True,
#      'name': 'Capstone Turbine Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPST',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '7a75a534-8ede-4fdb-bb75-36ae18bf95a0',
#      'marginable': True,
#      'name': 'Adial Pharmaceuticals, Inc Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ADIL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8ece6223-c699-4d88-b50f-4170ed6fd724',
#      'marginable': True,
#      'name': 'ADMA Biologics Inc Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ADMA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e6feab98-96b6-4099-8658-5ff2f76d9ed7',
#      'marginable': True,
#      'name': 'Capitala Finance Corp. 5.75% Convertible Notes Due 2022',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPTAG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '79ca1b49-18a9-47e9-989d-0357dee8612f',
#      'marginable': True,
#      'name': 'Capitala Finance Corp. 6% Notes Due 2022',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPTAL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '31af8dfd-365f-4bab-8b79-54611eaa3a2a',
#      'marginable': True,
#      'name': 'Calamos Long/Short Equity & Dynamic Income Trust Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': 'd5e8fc10-aa01-40cb-97dd-99def8a06528',
#      'marginable': True,
#      'name': 'Cheniere Energy Partners, LP',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CQP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '46e5f5b4-d67c-433c-8e80-9893631dbfc5',
#      'marginable': True,
#      'name': 'Crane Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd414546c-2622-4d1a-bf12-2a68636f5a87',
#      'marginable': True,
#      'name': 'CRA International, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRAI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '26f5c904-850b-4053-b1f4-d67d7b4f7706',
#      'marginable': True,
#      'name': 'VanEck Vectors Oil Refiners ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CRAK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'a9cbd8e5-04f7-4b50-89a6-0fe3c29842d2',
#      'marginable': True,
#      'name': 'iShares MSCI ACWI Low Carbon Target ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CRBN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '4852b574-c6dc-40b0-b5f9-f21c01d55cb7',
#      'marginable': True,
#      'name': 'Corbus Pharmaceuticals Holdings, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRBP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '12fa815b-a711-4166-b031-e23ed7459661',
#      'marginable': True,
#      'name': 'Crawford & Company Class A',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRD.A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'bfd95f49-1392-4002-990c-8fcb1d374f61',
#      'marginable': True,
#      'name': 'Crawford & Company Class B',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRD.B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a2ba3b18-54a9-439b-9b0f-2a0ef6a54453',
#      'marginable': True,
#      'name': 'Cree, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CREE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '61ed396c-3bac-4045-9dc2-d9ad2b5968f2',
#      'marginable': True,
#      'name': 'The Gabelli Go Anywhere Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GGO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '654197e3-c896-4b3d-929b-ab2c81a50209',
#      'marginable': True,
#      'name': 'Aptus Behavioral Momentum ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ADME',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9e2ca5f0-2552-439e-8a8e-bf47e3cc63cc',
#      'marginable': True,
#      'name': 'Adamis Pharmaceuticals Corporation Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ADMP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ae895f0c-6f40-40a5-8dc5-a97240d3ab61',
#      'marginable': True,
#      'name': 'Bank of America Corporation Depositary Shares, each representing '
#              'a 1/1,000 th interest in a share of',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BAC-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'dea659d7-4932-4918-be78-8c3a67f36bb7',
#      'marginable': True,
#      'name': 'China Recycling Energy Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CREG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '16104193-72c0-4571-b302-5ee0d69fdd87',
#      'marginable': True,
#      'name': 'Cresud S.A.C.I.F. y A. American Depositary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRESY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': 'c9e5125e-c6ed-4100-8fe3-806fdce56a46',
#      'marginable': True,
#      'name': 'Cornerstone Total Return Fund, Inc',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '74d801f7-df57-41e3-91f0-288b0f811a3e',
#      'marginable': True,
#      'name': 'CRH Public Limited Company',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CRH',
#      'tradable': True}),
#  ...]

# %%
# Create a new empty DataFrame
asset_info_df = pd.DataFrame()
asset_info_df['symbol'] = pd.Series([asset.symbol for asset in assets])

# Display the first 10 asset tickers
display(asset_info_df.head(10))
# Out:
#              symbol
# 0              LSAC
# 1               AXP
# 2               OIL
# 3               CCA
# 4                CY
# 5               NFO
# 6              CBPX
# 7     GRSH_DELISTED
# 8  N014776_DELISTED
# 9               KOR

# %% [markdown]
# ### Get 1 Year's Worth of Data via API Call and Read in as DataFrame

# %%
# Set the ticker
ticker = "AAPL"

# Set timeframe to '1D'
timeframe = '1D'

# Set start and end datetimes of 1 year, between now and 365 days ago.
end_date = datetime.now()
start_date = end_date + timedelta(-365)

# Format end_date and start_date with isoformat
end_date = pd.Timestamp(end_date, tz="America/New_York").isoformat()
start_date = pd.Timestamp(start_date, tz="America/New_York").isoformat()

# Get 1 year's worth of historical data for AAPL
df = api.get_barset(
    ticker,
    timeframe,
    limit=None,
    start=start_date,
    end=end_date,
    after=None,
    until=None,
).df

df.head()
# Out:
#                               AAPL
#                               open      high      low   close    volume
# 2019-05-07 00:00:00-04:00  205.880  207.4175  200.825  202.86  34328425
# 2019-05-08 00:00:00-04:00  201.900  205.3400  201.750  202.90  22729670
# 2019-05-09 00:00:00-04:00  200.400  201.6800  196.660  200.72  32427147
# 2019-05-10 00:00:00-04:00  197.419  198.8500  192.770  197.30  36118438
# 2019-05-13 00:00:00-04:00  187.710  189.4800  182.850  185.72  50491792

# %% [markdown]
# ### Drop Extraneous Levels and Columns

# %%
# Drop Outer Table Level
df = df.droplevel(axis=1, level=0)

# Use the drop function to drop extra columns
df.drop(columns=['open', 'high', 'low', 'volume'], inplace=True)

# Since this is daily data, we can keep only the date (remove the time) component of the data
df.index = df.index.date

df.head()
# Out:
#              close
# 2019-05-07  202.86
# 2019-05-08  202.90
# 2019-05-09  200.72
# 2019-05-10  197.30
# 2019-05-13  185.72

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Use the `pct_change` function to calculate daily returns of AAPL
daily_returns = df.pct_change()
daily_returns.head()
# Out:
#                close
# 2019-05-07       NaN
# 2019-05-08  0.000197
# 2019-05-09 -0.010744
# 2019-05-10 -0.017039
# 2019-05-13 -0.058692

# %% [markdown]
# ### Calculate Value of Average Daily Returns

# %%
# Use the `mean` function to calculate the mean of daily returns for AAPL
avg_daily_return = daily_returns.mean()['close']
avg_daily_return
# Out:
# 0.001894462078205318

# %% [markdown]
# ### Calculate Value of Standard Deviation of Daily Returns

# %%
# Use the `std` function to calculate the standard deviation of daily returns for AAPL
std_dev_daily_return = daily_returns.std()['close']
std_dev_daily_return
# Out:
# 0.02584574779666521

# %% [markdown]
# ### Run the Monte Carlo Simulation and Save Results to DataFrame

# %%
# Set number of trading days and get last closing price of AAPL from DataFrame
num_trading_days = 252
aapl_last_price = df['close'][-1]

# Initialize the simulated prices list with the last closing price of AAPL
simulated_aapl_prices = [aapl_last_price]

# Simulate the returns for 252 days
for i in range(num_trading_days):
    # Calculate the simulated price using the last price within the list
    simulated_price = simulated_aapl_prices[-1] * (1 + np.random.normal(avg_daily_return, std_dev_daily_return))
    # Append the simulated price to the list
    simulated_aapl_prices.append(simulated_price)
    
# Create a DataFrame of the simulated prices
simulated_price_df = pd.DataFrame({
    "Simulated AAPL Prices": simulated_aapl_prices
})

# Print head of DataFrame
simulated_price_df.head()
# Out:
#    Simulated AAPL Prices
# 0             300.500000
# 1             285.258436
# 2             286.221114
# 3             287.318998
# 4             293.703777

# %% [markdown]
# ### Plot the Simulated Stock Price Trajectory for AAPL over the Next Year (252 Trading Days)

# %%
# Use the `plot` function to plot the trajectory of AAPL stock based on a 252 trading day simulation
simulated_price_df.plot()

# %% [markdown]
# ### Calculate Daily Returns of Simulated Stock Prices for AAPL

# %%
# Use the `pct_change` function to calculate daily returns of simulated stock prices for AAPL
simulated_daily_returns = simulated_price_df.pct_change()
simulated_daily_returns.head()
# Out:
#    Simulated AAPL Prices
# 0                    NaN
# 1              -0.050721
# 2               0.003375
# 3               0.003836
# 4               0.022222

# %% [markdown]
# ### Calculate the Cumulative Returns of Simulated Stock Prices for AAPL

# %%
# Use the `cumprod` function to calculate the cumulative returns of simulated stock prices for AAPL
simulated_cumulative_returns = (1 + simulated_daily_returns).cumprod()
simulated_cumulative_returns.head()
# Out:
#    Simulated AAPL Prices
# 0                    NaN
# 1               0.949279
# 2               0.952483
# 3               0.956136
# 4               0.977384

# %% [markdown]
# ### Calculate the Cumulative Profits/Losses of Simulated Stock Prices for AAPL

# %%
# Multiply an initial investment by the cumulative returns of simulative stock prices to
# return the progression of cumulative returns in terms of money
initial_investment = 10000
cumulative_pnl = initial_investment * simulated_cumulative_returns
cumulative_pnl.head()
# Out:
#    Simulated AAPL Prices
# 0                    NaN
# 1            9492.793214
# 2            9524.829069
# 3            9561.364310
# 4            9773.836158

# %% [markdown]
# ### Plot the Cumulative Profits/Losses of `$10,000` in AAPL Over the Next `252` Trading Days

# %%
# Use the 'plot' function to create a chart of the cumulative profits/losses
cumulative_pnl.plot()
